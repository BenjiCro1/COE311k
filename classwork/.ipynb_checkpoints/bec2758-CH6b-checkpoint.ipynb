# %%
import numpy as np
import time

# %%
def gauss_seidel(A, b, x0, tol, max_iterations):
    start = time.perf_counter()
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i))
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            end = time.perf_counter() - start
            return x_new, k, end
        x = x_new
    end = time.perf_counter() - start
    return x, max_iterations, end

# %%
def jacobi(A, b, x0, tol, max_iterations):
    start = time.perf_counter()
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            end = time.perf_counter() - start
            return x_new, k, end
        x = x_new
    end = time.perf_counter() - start
    return x, max_iterations, end

# %%
A = np.array([[1, 2, 3, 0, 0],
            [2, 1, 2, 3, 0],
            [3, 2, 1, 2, 3],
            [0, 3, 2, 1, 2],
            [0, 0, 3, 2, 1]], dtype=float)
b = np.array([14, 22, 33, 26, 22], dtype=float)
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations, time1 = gauss_seidel(A, b, x0, tol, max_iterations)
print(f"Solution for gauss: {solution}")
print(f"Iterations for gauss: {iterations}")
print(f"Time for gauss: {time1}")
solution2, iterations2, time2 = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution for jacobi: {solution2}")
print(f"Iterations for jacobi: {iterations2}")
print(f"Time for jacobi: {time2}")
# Out:
# Solution for gauss: [-8.70303388e+112  3.37515847e+113 -5.07312279e+113 -1.50300774e+113
#   1.82253839e+114]
# Iterations for gauss: 100
# Time for gauss: 0.006302583962678909
# Solution for jacobi: [-3.43010894e+85 -4.24934579e+85 -5.28966155e+85 -4.24934579e+85
#  -3.43010894e+85]
# Iterations for jacobi: 100
# Time for jacobi: 0.006129711866378784

# %% [markdown]
# Increasing the number of max iterations results in data lost in overflow so it is fair to assume that this system does not converge.
